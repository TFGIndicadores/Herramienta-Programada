# %%
import flet as ft
from flet import (
    ElevatedButton,
    FilePicker,
    FilePickerResultEvent,
    Page,
    Row,
    Text,
    icons,
    Ref
)

# %%
def main2(page: ft.Page):
    page.title = "Herramienta Programada TFG"
    page.vertical_alignment = ft.MainAxisAlignment.CENTER
    page.theme_mode = 'light'
    page.padding = 20
    page.window_width = 800
    page.window_height = 500
    page.add(
        ft.DataTable(
            columns=[
                ft.DataColumn(ft.Text("Indicador")),
                ft.DataColumn(ft.Text("Meta")),
                ft.DataColumn(ft.Text("Mayor que/Menor que"), numeric=True),
            ],
            rows=[
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("CAPACIDAD MAXIMA PRÁCTICA")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("HORAS PROGRAMADAS PARA LA ATENCION DE PERSONAS")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("ESTANDAR PACIENTE POR HORA DE LA UNIDAD")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
            ],
        ),
    )

#ft.app(target=main2)

# %%
def main(page: Page):
    
    page.title = "Herramienta Programada TFG"
    page.vertical_alignment = ft.MainAxisAlignment.CENTER
    page.theme_mode = 'light'
    page.padding = 20
    page.window_width = 800
    page.window_height = 500

    cargar_ind = Ref[ElevatedButton]()
    
    def validar_carga():
        return not (excel_consol.value and excel_form.value)
            

    # Seleccionar archivos de excel
    def select_consol(e: FilePickerResultEvent):
        excel_consol.value = (
            ", ".join(map(lambda f: f.name, e.files)) if e.files else "Cancelado"
        )
        excel_consol.update()
        cargar_ind.current.disabled = validar_carga()
        page.update()
        

    select_first_file = FilePicker(on_result=select_consol)
    excel_consol = Text()


    def select_form(e: FilePickerResultEvent):
        excel_form.value = (
            ", ".join(map(lambda f: f.name, e.files)) if e.files else "Cancelado"
        )
        excel_form.update()
        cargar_ind.current.disabled = validar_carga()
        page.update()
    select_third_file = FilePicker(on_result=select_form)
    excel_form = Text()


    def func_ind(e):
        #HELP NEEDED HERE
        print(excel_consol)
        print(excel_form)
        print("aasdasd")
        #funcion de indicadores


    page.overlay.extend([select_first_file,select_third_file])

    page.add(
        Row(
            [
                Text(value="Favor indicar Mes y Año correspondientes",width = 275)]),
        Row([
        ft.Dropdown(
            label="Mes",
            options=[
                ft.dropdown.Option("Octubre"),
                ft.dropdown.Option("Noviembre"),
                ft.dropdown.Option("Diciembre"),
            ])
            ,
        ft.Dropdown(
            label="Año",
            options=[
                ft.dropdown.Option("2023"),
                ft.dropdown.Option("2024"),
                ft.dropdown.Option("2025"),
            ])
        ])
        ,

        Row(
            [
                Text(value="Favor seleccionar los archivos",width = 275)]),
        Row(
            [
                Text(value="Cargar el consolidado mensual",width = 275),
                ElevatedButton(
                    "Cargar Archivo", width = 200,
                    icon=icons.UPLOAD_FILE,
                    on_click=lambda _: select_first_file.pick_files(
                        allow_multiple=False
                    ), 
                ),
                excel_consol,
            ]
        ),    
        Row(
            [
                Text(value="Cargar el Formulario de datos adicionales",width = 275),
                ElevatedButton(
                    "Cargar Archivo", width = 200,
                    icon=icons.UPLOAD_FILE,
                    on_click=lambda _: select_third_file.pick_files(
                        allow_multiple=False
                    ),
                ),
                excel_form,
            ]
        ),
        Row(
            [
                Text(value="Ejecutar Herramienta Programada",width = 275),
                ElevatedButton(
                    "Cargar Indicadores", width = 200,
                    ref=cargar_ind,
                    icon=icons.UPLOAD,
                    on_click=func_ind,
                    disabled=True,
                    )
            ]
        )       
    )
ft.app(target=main)
# Out:
# Exception in thread Thread-618 (func_ind):
# Traceback (most recent call last):
#   File "c:\Users\anjos\Anaconda3\envs\Curso_Udemy\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "c:\Users\anjos\Anaconda3\envs\Curso_Udemy\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16616\2474440396.py", line 43, in func_ind
# AttributeError: 'Text' object has no attribute 'text'

# %%
def main2(page: ft.Page):
    page.title = "Herramienta Programada TFG"
    page.vertical_alignment = ft.MainAxisAlignment.CENTER
    page.theme_mode = 'light'
    page.padding = 20
    page.window_width = 800
    page.window_height = 500
    page.add(
        ft.DataTable(
            columns=[
                ft.DataColumn(ft.Text("Indicador")),
                ft.DataColumn(ft.Text("Meta")),
                ft.DataColumn(ft.Text("Mayor que/Menor que"), numeric=True),
            ],
            rows=[
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("CAPACIDAD MAXIMA PRÁCTICA")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("HORAS PROGRAMADAS PARA LA ATENCION DE PERSONAS")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
                ft.DataRow(
                    cells=[
                        ft.DataCell(ft.Text("ESTANDAR PACIENTE POR HORA DE LA UNIDAD")),
                        ft.DataCell(ft.TextField(border="none")),
                        ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                    ],
                ),
            ],
        ),
    )

ft.app(target=main2)

# %%
import flet as ft

meses = ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto", "Setiembre", "Octubre", "Noviembre", "Diciembre"]

for mes in meses:
    meslist = []
    meslist.append(ft.dropdown.Option(mes))


def main(page: ft.Page):

    page.title = "Herramienta Programada TFG"
    page.vertical_alignment = ft.MainAxisAlignment.CENTER
    page.theme_mode = 'light'
    page.padding = 20
    page.window_width = 800
    page.window_height = 500

    cargar_ind = Ref[ElevatedButton]()
    


    def validar_carga():
        return not (excel_consol.value and excel_form.value)        

    # Seleccionar archivos de excel
    def select_consol(e: FilePickerResultEvent):
        excel_consol.value = (
            ", ".join(map(lambda f: f.name, e.files)) if e.files else "Cancelado"
        )
        excel_consol.update()
        cargar_ind.current.disabled = validar_carga()
        page.update()
        

    select_first_file = FilePicker(on_result=select_consol)
    excel_consol = Text()


    def select_form(e: FilePickerResultEvent):
        excel_form.value = (
            ", ".join(map(lambda f: f.name, e.files)) if e.files else "Cancelado"
        )
        excel_form.update()
        cargar_ind.current.disabled = validar_carga()
        page.update()
    select_third_file = FilePicker(on_result=select_form)
    excel_form = Text()


    def func_ind(e):
        print("test")
        #ft.app(target=main2)
        #funcion de indicadores

    def checkbox_change():
        cargar_ind.current.disabled = validar_carga()
    

    page.overlay.extend([select_first_file,select_third_file])






    t = ft.Tabs(

        selected_index=0,
        animation_duration=300,
        tabs=[


            ft.Tab(

                text="Principal",
                content= 
                    ft.Column([
                    Row([Text(value="Favor indicar Mes y Año correspondientes",width = 275)]),
                    Row([
                        ft.Dropdown(
                        label="Mes",
                        options=meslist),
                        ft.Dropdown(
                        label="Año",
                        options=[
                            ft.dropdown.Option("2023"),
                            ft.dropdown.Option("2024"),
                            ft.dropdown.Option("2025")])
                        ]),
                    Row([Text(value="Favor seleccionar los archivos",width = 275)]),
                    Row(
                        [
                            Text(value="Cargar el consolidado mensual",width = 275),
                            ElevatedButton(
                                "Cargar Archivo", width = 200,
                                icon=icons.UPLOAD_FILE,
                                on_click=lambda _: select_first_file.pick_files(
                                    allow_multiple=False
                                ), 
                            ),
                            excel_consol,
                        ]
                    ),    
                    Row(
                        [
                            Text(value="Cargar el Formulario de datos adicionales",width = 275),
                            ElevatedButton(
                                "Cargar Archivo", width = 200,
                                icon=icons.UPLOAD_FILE,
                                on_click=lambda _: select_third_file.pick_files(
                                    allow_multiple=False
                                ),
                            ),
                            excel_form,
                        ]
                    ),

                    Row([
                        
                        Text(value="Validar metas de indicadores",width = 275),
                        ft.Checkbox(label="Completado", value=False, on_change=checkbox_change),
                        ElevatedButton(
                                "Metas", #width = 200,
                                icon=icons.UPLOAD_FILE,
                                #on_click = 
                            )
                        ]),     

                    Row(
                        [
                            Text(value="Ejecutar Herramienta Programada",width = 275),
                            ElevatedButton(
                                "Cargar Indicadores", width = 200,
                                ref=cargar_ind,
                                icon=icons.UPLOAD,
                                on_click=func_ind,
                                disabled=True,
                                )
                        ]
                    )       

                    ]) #cierra el column     
    

            ),



            ft.Tab(

                text="Metas de indicadores",
                icon=ft.icons.SETTINGS,
                content=ft.Container(
                    content=ft.DataTable(
                                    columns=[
                                        ft.DataColumn(ft.Text("Indicador")),
                                        ft.DataColumn(ft.Text("Meta")),
                                        ft.DataColumn(ft.Text("Mayor que/Menor que"), numeric=True),
                                            ],
                                    rows=[
                                        ft.DataRow(
                                                cells=[
                                                    ft.DataCell(ft.Text("CAPACIDAD MAXIMA PRÁCTICA")),
                                                    ft.DataCell(ft.TextField(border="none")),
                                                    ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                                                    ],
                                                ),

                                        ft.DataRow(
                                                cells=[
                                                    ft.DataCell(ft.Text("HORAS PROGRAMADAS PARA LA ATENCION DE PERSONAS")),
                                                    ft.DataCell(ft.TextField(border="none")),
                                                    ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                                                    ],
                                                ),

                                        ft.DataRow(
                                                cells=[
                                                    ft.DataCell(ft.Text("ESTANDAR PACIENTE POR HORA DE LA UNIDAD")),
                                                    ft.DataCell(ft.TextField(border="none")),
                                                    ft.DataCell(ft.Dropdown(border="none",options=[ft.dropdown.Option("Mayor qué"),ft.dropdown.Option("Menor qué")])),
                                                    ],
                                                ),   
                                           ],
                                        )
                                    ),
                 )       
             ],
        expand=1,
    )

    page.add(t)

ft.app(target=main)
# Out:
# test
# test
# test
# test
# test
# test
# test
# test
